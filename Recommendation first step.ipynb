# %%
import os
import pandas as pd
import numpy as np
import time
path = os.path.dirname(os.path.realpath('__file__'))
print(path)
start_time = time.time()

rate = pd.read_csv(path + '\\ML\\ratings.csv')
print(rate)
end_time = time.time()
print(end_time - start_time)
# Out:
# C:\Users\Rowida Nagah
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 5            1       70     3.0   964982400
# 6            1      101     5.0   964980868
# 7            1      110     4.0   964982176
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# 10           1      163     5.0   964983650
# 11           1      216     5.0   964981208
# 12           1      223     3.0   964980985
# 13           1      231     5.0   964981179
# 14           1      235     4.0   964980908
# 15           1      260     5.0   964981680
# 16           1      296     3.0   964982967
# 17           1      316     3.0   964982310
# 18           1      333     5.0   964981179
# 19           1      349     4.0   964982563
# ...

# %%
import os
import pandas as pd
import numpy as np
path = os.path.dirname(os.path.realpath('__file__'))
print(path)
m = pd.read_csv(path + '\\ML\\ratings.csv')
print(m)
end_time = time.time()
print(end_time - start_time)
# Out:
# C:\Users\Rowida Nagah
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 5            1       70     3.0   964982400
# 6            1      101     5.0   964980868
# 7            1      110     4.0   964982176
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# 10           1      163     5.0   964983650
# 11           1      216     5.0   964981208
# 12           1      223     3.0   964980985
# 13           1      231     5.0   964981179
# 14           1      235     4.0   964980908
# 15           1      260     5.0   964981680
# 16           1      296     3.0   964982967
# 17           1      316     3.0   964982310
# 18           1      333     5.0   964981179
# 19           1      349     4.0   964982563
# ...

# %%
C = rate["movieId"].mean()
C
# Out:
# 19435.2957177992

# %%
from itertools import groupby
v = [len(list(group)) for key, group in groupby(rate["movieId"])]
len(v)
# Out:
# 100836

# %%
a = [1,3,9,1,2,2,2,2,3,3,4,5,5]
from itertools import groupby
[len(list(group)) for key, group in groupby(a)]
# Out:
# [1, 1, 1, 1, 4, 2, 1, 2]

# %%
x = sorted(rate["movieId"])
from itertools import groupby
x=[len(list(group)) for key, group in groupby(x)]
# Out:
# [215,
#  110,
#  52,
#  7,
#  49,
#  102,
#  54,
#  8,
#  16,
#  132,
#  70,
#  19,
#  8,
#  18,
#  13,
#  82,
#  67,
#  20,
#  88,
#  15,
#  89,
#  36,
#  16,
#  28,
#  76,
#  13,
#  9,
#  11,
#  38,
#  3,
#  38,
#  177,
#  128,
#  67,
#  4,
#  104,
#  2,
#  15,
#  7,
#  8,
#  46,
#  32,
#  15,
#  203,
#  68,
#  1,
#  204,
#  28,
#  2,
#  3,
#  1,
#  8,
#  37,
#  34,
#  6,
#  80,
#  7,
#  5,
#  31,
#  9,
#  5,
#  20,
#  55,
#  5,
#  7,
#  13,
#  8,
#  5,
#  15,
#  1,
#  3,
#  17,
#  2,
#  14,
#  8,
#  1,
#  7,
#  15,
#  7,
#  16,
#  10,
#  8,
#  9,
#  10,
#  84,
#  1,
#  10,
#  2,
#  14,
#  23,
#  5,
#  3,
#  99,
#  23,
#  1,
#  26,
#  1,
#  237,
#  104,
#  46,
#  3,
#  5,
#  1,
#  2,
#  2,
#  2,
#  16,
#  4,
#  12,
#  7,
#  1,
#  1,
#  6,
#  31,
#  1,
#  16,
#  86,
#  12,
#  51,
#  3,
#  15,
#  1,
#  1,
#  201,
#  44,
#  2,
#  137,
#  12,
#  6,
#  3,
#  11,
#  62,
#  14,
#  57,
#  103,
#  17,
#  66,
#  14,
#  144,
#  3,
#  54,
#  10,
#  35,
#  6,
#  53,
#  62,
#  10,
#  20,
#  13,
# ...

# %%
city_names = pd.Series(['Francisco', 'Jose', 'Alex'])
city_names
# Out:
# 0    Francisco
# 1         Jose
# 2         Alex
# dtype: object

# %%
population = pd.Series([852469, 1015785, 485199])
population
# Out:
# 0     852469
# 1    1015785
# 2     485199
# dtype: int64

# %%
pd.DataFrame({ 'City name': city_names, 'Population': population })
# Out:
#    City name  Population
# 0  Francisco      852469
# 1       Jose     1015785
# 2       Alex      485199
